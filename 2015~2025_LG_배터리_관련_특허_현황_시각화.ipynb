# %% [markdown]
# <a href="https://colab.research.google.com/github/cjsdudwls1/simple_things/blob/main/2015~2025_LG_%EB%B0%B0%ED%84%B0%EB%A6%AC_%EA%B4%80%EB%A0%A8_%ED%8A%B9%ED%97%88_%ED%98%84%ED%99%A9_%EC%8B%9C%EA%B0%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 나눔 폰트 설치
# !sudo apt-get install -y fonts-nanum > /dev/null
# !sudo fc-cache -fv > /dev/null
# matplotlib 캐시 제거
# !rm -rf ~/.cache/matplotlib
# Out:
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# NanumBarunGothic 폰트를 기본 폰트로 설정
plt.rc('font', family='NanumBarunGothic')

# 그래프에서 마이너스(-) 부호가 깨지는 현상 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
import matplotlib.pyplot as plt

# 데이터 준비
data = [10, 20, 30, 40]
labels = ['사과', '바나나', '딸기', '포도']

# 폰트 설정이 되어 있다고 가정
# 만약 폰트 설정이 안 되어 있다면 이전 답변의 1~3단계를 먼저 실행해야 합니다.

plt.figure(figsize=(6, 4))
plt.bar(labels, data, color=['red', 'yellow', 'pink', 'purple'])

# 한글 제목
plt.title('과일별 판매량 테스트', fontsize=15)
# 한글 축 레이블
plt.xlabel('과일 종류')
plt.ylabel('판매량')

plt.show()

# %% [markdown]
# # 크롤링 완료한 2015-2025 배터리 및 ess 관련 특허 데이터 로드
# 데이터 출처: https://www.kipris.or.kr
#
# 데이터 검색식: "이차전지 배터리 + 배터리 + ESS + (에너지 저장기술)"

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/pin - 복사본.xlsx'
df = pd.read_excel(file_path)
display(df.head())
# Out:
#                                                발명의명칭  \
# 0           에너지저장시스템(ESS)에 포함된 배터리 모듈의 냉각 시스템 및 그 방법
# 1  ESS, 충전기, 충전소, 파워뱅크, 폐배터리, 전기장치 및 이가 이용되는 공사, ...
# 2        지하철 및 트램용 레독스 플로우 ESS/리튬 이차전지 하이브리드 에너지 시스템
# 3     배터리 방전을 예방할 수 있는 전기자동차의 축전지를 기반으로 하는 ESS 운영시스템
# 4                       블루투스 통신을 이용한 ESS용 배터리 관리 시스템
#
#                                            발명의명칭(영문)  \
# 0  cooling system of battery module included in e...
# 1  ess, charger, powerbank, battery, electric too...
# 2  redox flow ess/lithium secondary battery hybri...
# 3  ess operation system based on storage battery ...
# 4  battery management system for ess using blueto...
#
#                                                IPC분류  \
# 0  H01M 10/63(2014.01)|H01M 10/6563(2014.01)|H01M...
# 1             H02J 7/00(2006.01)|H01M 10/54(2006.01)
# 2  H02J 3/32(2006.01)|H01M 8/18(2015.01)|H01M 8/0...
# 3  B60L 3/00(2019.01)|B60L 53/20(2019.01)|H02J 3/...
# 4  H02J 3/32(2006.01)|H02J 3/38(2022.01)|G06Q 50/...
#
#                                                CPC분류           출원번호  \
# 0  H01M 10/63(2022.01)|H01M 10/6563(2015.04)|H01M...  1020190134646
# 1             H02J 7/00(2013.01)|H01M 10/54(2013.01)  1020220137853
# 2  H02J 3/32(2013.01)|H01M 8/188(2013.01)|H01M 8/...  1020200165202
# 3  B60L 3/0046(2019.02)|B60L 53/20(2019.02)|H02J ...  1020190119308
# 4  H02J 3/32(2020.01)|H02J 3/381(2020.01)|G06Q 50...  1020180171565
#
#          출원일자                           출원인  번역문제출일자          등록번호  \
# 0  2019.10.28  주식회사 엘지에너지솔루션(서울특별시 영등포구...)      NaN           NaN
# 1  2022.10.25      주식회사 한국산업기술원(서울특별시 구...)      NaN           NaN
# 2  2020.11.30  주식회사 엘지에너지솔루션(서울특별시 영등포구...)      NaN           NaN
# 3  2019.09.27              정인호(경상북도 성주군...)      NaN  1.022789e+12
# 4  2018.12.28    주식회사 유비넷시스(경기도 용인시 기흥구...)      NaN           NaN
#
#          등록일자  ...  관련출원번호     심사청구여부(일자)  심사청구항수  \
# 0         NaN  ...     NaN  Y(2022.07.28)      12
# 1         NaN  ...     NaN  Y(2022.10.25)       1
# 2         NaN  ...     NaN  Y(2022.09.19)       9
# 3  2021.07.13  ...     NaN  Y(2019.09.27)       1
# 4         NaN  ...     NaN  Y(2018.12.28)       4
#
#                                                   요약  \
# 0  본 발명은 배터리 모듈의 냉각 시스템 및 그 방법에 관한 것으로서, 보다 구체적으로...
# 1  본 발명은 a) 배터리, 폐배터리, ESS, 파워뱅크, 에너지저장시스템; b) 폐배...
# 2  본 발명의 일 실시예에 따른 하이브리드 에너지 시스템은, 전력망 및 적어도 하나의 ...
# 3  본 발명은 배터리 방전을 예방할 수 있는 전기자동차의 축전지를 기반으로 하는 ESS...
# 4  본 발명은 블루투스 통신을 이용한 ESS용 배터리 관리 시스템에 관한 것으로서, 구...
#
#                                                  발명자  \
# 0                                  박준철(대전광역시 유성구...)
# 1                                    정하익(경기도 파주시...)
# 2  신동환(대전광역시 유성구...)|안수준(대전광역시 유성구...)|최범(대전광역시 유...
# 3                                   정인호(경상북도 성주군...)
# 4                                이진주(경기도 용인시 기흥구...)
#
#                                                  대리인             최종권리자 지정국  \
# 0            이강민(서울 강남구 역삼로 *** (역삼동) *층(아인특허법률사무소))               NaN NaN
# 1                                                NaN               NaN NaN
# 2        특허법인필앤온지(서울특별시 서초구 서초중앙로 **, *층(서초동, 준영빌딩))               NaN NaN
# 3  특허법인 대연(대구광역시 달서구 달서대로 ***, ***호 (신당동, E&C이노비즈...  정인호(경상북도 성주군...) NaN
# 4  특허법인(유한) 해담(서울특별시 강남구 논현로 ***, **층 *호(역삼동, 송촌빌딩))               NaN NaN
#
#   피인용 횟수                                                청구항
# 0    NaN  [청구항1]적어도 둘 이상의 배터리 모듈을 포함하는 배터리 랙을 하나 이상 포함하여...
# 1    NaN  [청구항1]공사에 있어서, 사용된 후 폐기된 배터리와,상기 배터리가 포함되는 파워뱅...
# 2    NaN  [청구항1]전력망 및 적어도 하나의 신재생 발전 장치로부터 전력을 공급 받아 저장하...
# 3    NaN  [청구항1]삭제\n[청구항2]전력충전 및 공급부(10)로부터 교류전력을 공급 받아 ...
# 4    NaN  [청구항1]구동전원을 제공하는 배터리와, 상기 배터리의 DC 전원을 AC 전원으로 ...
#
# [5 rows x 33 columns]

# %% [markdown]
# # LG관련 데이터만 필터링

# %%
search_terms = ['lg', 'LG', '엘지', '엘쥐']
pattern = '|'.join(search_terms)

df_filtered = df[df['출원인'].str.contains(pattern, case=False, na=False)]

display(df_filtered.head())
# Out:
#                                           발명의명칭  \
# 0      에너지저장시스템(ESS)에 포함된 배터리 모듈의 냉각 시스템 및 그 방법
# 2   지하철 및 트램용 레독스 플로우 ESS/리튬 이차전지 하이브리드 에너지 시스템
# 5                        가스배출 구조를 구비한 ESS 배터리 팩
# 11                ESS 내 개별 배터리 랙별 절연 감지 장치 및 방법
# 13                에너지저장시스템(ESS)의 셀 안정화 방법 및 시스템
#
#                                             발명의명칭(영문)  \
# 0   cooling system of battery module included in e...
# 2   redox flow ess/lithium secondary battery hybri...
# 5     ess battery pack with a gas discharge structure
# 11  apparatus and method for sensing individual ba...
# 13  cell stabilization method and system of energy...
#
#                                                 IPC분류  \
# 0   H01M 10/63(2014.01)|H01M 10/6563(2014.01)|H01M...
# 2   H02J 3/32(2006.01)|H01M 8/18(2015.01)|H01M 8/0...
# 5   H01M 50/317(2021.01)|H01M 50/333(2021.01)|H01M...
# 11  H01M 10/48(2021.01)|H01M 10/42(2014.01)|H01M 5...
# 13  H01M 10/44(2006.01)|H01M 10/42(2014.01)|G01R 3...
#
#                                                 CPC분류           출원번호  \
# 0   H01M 10/63(2022.01)|H01M 10/6563(2015.04)|H01M...  1020190134646
# 2   H02J 3/32(2013.01)|H01M 8/188(2013.01)|H01M 8/...  1020200165202
# 5   H01M 50/317(2021.01)|H01M 50/333(2021.01)|H01M...  1020200132208
# 11  H01M 10/48(2022.01)|H01M 10/425(2013.01)|H01M ...  1020180157379
# 13  H01M 10/441(2013.01)|H01M 10/4207(2013.01)|G01...  1020190103486
#
#           출원일자                           출원인  번역문제출일자          등록번호  \
# 0   2019.10.28  주식회사 엘지에너지솔루션(서울특별시 영등포구...)      NaN           NaN
# 2   2020.11.30  주식회사 엘지에너지솔루션(서울특별시 영등포구...)      NaN           NaN
# 5   2020.10.13  주식회사 엘지에너지솔루션(서울특별시 영등포구...)      NaN           NaN
# 11  2018.12.07  주식회사 엘지에너지솔루션(서울특별시 영등포구...)      NaN  1.026171e+12
# 13  2019.08.23  주식회사 엘지에너지솔루션(서울특별시 영등포구...)      NaN  1.027856e+12
#
#           등록일자  ...  관련출원번호     심사청구여부(일자)  심사청구항수  \
# 0          NaN  ...     NaN  Y(2022.07.28)      12
# 2          NaN  ...     NaN  Y(2022.09.19)       9
# 5          NaN  ...     NaN  Y(2023.08.14)      10
# 11  2023.12.19  ...     NaN  Y(2021.10.06)       8
# 13  2025.03.19  ...     NaN  Y(2022.07.15)      12
#
#                                                    요약  \
# 0   본 발명은 배터리 모듈의 냉각 시스템 및 그 방법에 관한 것으로서, 보다 구체적으로...
# 2   본 발명의 일 실시예에 따른 하이브리드 에너지 시스템은, 전력망 및 적어도 하나의 ...
# 5   본 발명에 따른 ESS 배터리 팩은 배터리 셀들을 수용할 수 있게 마련된 팩 케이스...
# 11  본 발명은 실시 예에 따른 ESS는, 복수개의 배터리 랙 각각의 제1(+)출력단이 ...
# 13  본 발명은 에너지저장시스템(ESS)의 셀 안정화 방법 및 시스템에 관한 것으로서, ...
#
#                                                   발명자  \
# 0                                   박준철(대전광역시 유성구...)
# 2   신동환(대전광역시 유성구...)|안수준(대전광역시 유성구...)|최범(대전광역시 유...
# 5                                   김송권(대전광역시 유성구...)
# 11  조항진(대전광역시 유성구...)|이종수(대전광역시 유성구...)|이지원(대전광역시 ...
# 13                                  임보미(대전광역시 유성구...)
#
#                                             대리인                         최종권리자  \
# 0       이강민(서울 강남구 역삼로 *** (역삼동) *층(아인특허법률사무소))                           NaN
# 2   특허법인필앤온지(서울특별시 서초구 서초중앙로 **, *층(서초동, 준영빌딩))                           NaN
# 5   특허법인필앤온지(서울특별시 서초구 서초중앙로 **, *층(서초동, 준영빌딩))                           NaN
# 11      이강민(서울 강남구 역삼로 *** (역삼동) *층(아인특허법률사무소))  주식회사 엘지에너지솔루션(서울특별시 영등포구...)
# 13      이강민(서울 강남구 역삼로 *** (역삼동) *층(아인특허법률사무소))  주식회사 엘지에너지솔루션(서울특별시 영등포구...)
#
#    지정국 피인용 횟수                                                청구항
# 0  NaN    NaN  [청구항1]적어도 둘 이상의 배터리 모듈을 포함하는 배터리 랙을 하나 이상 포함하여...
# 2  NaN    NaN  [청구항1]전력망 및 적어도 하나의 신재생 발전 장치로부터 전력을 공급 받아 저장하...
# 5  NaN    NaN  [청구항1]배터리 셀들을 수용할 수 있게 마련된 팩 케이스;상기 팩 케이스의 상부 ...
# 11 NaN    1.0  [청구항1]복수개의 배터리 랙들이 병렬 연결되어 있는 ESS에 있어서,상기 복수개의...
# 13 NaN    NaN  [청구항1]에너지저장시스템(ESS)에 포함된 각 배터리 모듈을 구성하는 다수의 셀들...
#
# [5 rows x 33 columns]

# %%
df_filtered
# Out:
#                                               발명의명칭  \
# 0          에너지저장시스템(ESS)에 포함된 배터리 모듈의 냉각 시스템 및 그 방법
# 2       지하철 및 트램용 레독스 플로우 ESS/리튬 이차전지 하이브리드 에너지 시스템
# 5                            가스배출 구조를 구비한 ESS 배터리 팩
# 11                    ESS 내 개별 배터리 랙별 절연 감지 장치 및 방법
# 13                    에너지저장시스템(ESS)의 셀 안정화 방법 및 시스템
# ...                                             ...
# 121657                                       전자디바이스
# 121659                     와치 타입의 이동 단말기 및 그의 동작 방법
# 121661                               이동단말기 및 그 제어방법
# 121665                                       이동 단말기
# 121669                               이동단말기 및 그 제어방법
#
#                                                 발명의명칭(영문)  \
# 0       cooling system of battery module included in e...
# 2       redox flow ess/lithium secondary battery hybri...
# 5         ess battery pack with a gas discharge structure
# 11      apparatus and method for sensing individual ba...
# 13      cell stabilization method and system of energy...
# ...                                                   ...
# 121657                                  electronic device
# 121659  watch-type mobile terminal operating method th...
# 121661  mobile terminal and method for controlling the...
# 121665                                    mobile terminal
# 121669  mobile terminal and method for controlling the...
#
#                                                     IPC분류  \
# 0       H01M 10/63(2014.01)|H01M 10/6563(2014.01)|H01M...
# 2       H02J 3/32(2006.01)|H01M 8/18(2015.01)|H01M 8/0...
# 5       H01M 50/317(2021.01)|H01M 50/333(2021.01)|H01M...
# 11      H01M 10/48(2021.01)|H01M 10/42(2014.01)|H01M 5...
# 13      H01M 10/44(2006.01)|H01M 10/42(2014.01)|G01R 3...
# ...                                                   ...
# 121657                               G06F 3/0354(2013.01)
# 121659            G06F 3/048(2021.01)|G04G 21/00(2010.01)
# 121661  H04M 1/725(2021.01)|G06F 3/0488(2013.01)|G06F ...
# 121665  H04M 1/725(2021.01)|H04M 1/02(2006.01)|G06F 3/...
# 121669                               G06F 3/0488(2013.01)
#
#                                                     CPC분류           출원번호  \
# 0       H01M 10/63(2022.01)|H01M 10/6563(2015.04)|H01M...  1020190134646
# 2       H02J 3/32(2013.01)|H01M 8/188(2013.01)|H01M 8/...  1020200165202
# 5       H01M 50/317(2021.01)|H01M 50/333(2021.01)|H01M...  1020200132208
# 11      H01M 10/48(2022.01)|H01M 10/425(2013.01)|H01M ...  1020180157379
# 13      H01M 10/441(2013.01)|H01M 10/4207(2013.01)|G01...  1020190103486
# ...                                                   ...            ...
# 121657                              G06F 3/03545(2013.01)  1020150087331
# 121659            G06F 3/048(2013.01)|G04G 21/00(2013.01)  1020150074062
# 121661  H04M 1/724(2013.01)|G06F 3/04883(2013.01)|G06F...  1020150104320
# 121665  H04M 1/72448(2013.01)|H04M 1/0202(2013.01)|H04...  1020150044430
# 121669                               G06F 3/0488(2013.01)  1020150016640
#
#               출원일자                           출원인  번역문제출일자          등록번호  \
# 0       2019.10.28  주식회사 엘지에너지솔루션(서울특별시 영등포구...)      NaN           NaN
# 2       2020.11.30  주식회사 엘지에너지솔루션(서울특별시 영등포구...)      NaN           NaN
# 5       2020.10.13  주식회사 엘지에너지솔루션(서울특별시 영등포구...)      NaN           NaN
# 11      2018.12.07  주식회사 엘지에너지솔루션(서울특별시 영등포구...)      NaN  1.026171e+12
# 13      2019.08.23  주식회사 엘지에너지솔루션(서울특별시 영등포구...)      NaN  1.027856e+12
# ...            ...                           ...      ...           ...
# 121657  2015.06.19      엘지전자 주식회사(서울특별시 영등포구...)      NaN           NaN
# 121659  2015.05.27      엘지전자 주식회사(서울특별시 영등포구...)      NaN           NaN
# 121661  2015.07.23      엘지전자 주식회사(서울특별시 영등포구...)      NaN           NaN
# 121665  2015.03.30      엘지전자 주식회사(서울특별시 영등포구...)      NaN           NaN
# 121669  2015.02.03      엘지전자 주식회사(서울특별시 영등포구...)      NaN           NaN
#
#               등록일자  ...  관련출원번호     심사청구여부(일자)  심사청구항수  \
# 0              NaN  ...     NaN  Y(2022.07.28)      12
# 2              NaN  ...     NaN  Y(2022.09.19)       9
# 5              NaN  ...     NaN  Y(2023.08.14)      10
# 11      2023.12.19  ...     NaN  Y(2021.10.06)       8
# 13      2025.03.19  ...     NaN  Y(2022.07.15)      12
# ...            ...  ...     ...            ...     ...
# 121657         NaN  ...     NaN              N      16
# 121659         NaN  ...     NaN              N      15
# 121661         NaN  ...     NaN              N       5
# 121665         NaN  ...     NaN              N      16
# 121669         NaN  ...     NaN              N      15
#
#                                                        요약  \
# 0       본 발명은 배터리 모듈의 냉각 시스템 및 그 방법에 관한 것으로서, 보다 구체적으로...
# 2       본 발명의 일 실시예에 따른 하이브리드 에너지 시스템은, 전력망 및 적어도 하나의 ...
# 5       본 발명에 따른 ESS 배터리 팩은 배터리 셀들을 수용할 수 있게 마련된 팩 케이스...
# 11      본 발명은 실시 예에 따른 ESS는, 복수개의 배터리 랙 각각의 제1(+)출력단이 ...
# 13      본 발명은 에너지저장시스템(ESS)의 셀 안정화 방법 및 시스템에 관한 것으로서, ...
# ...                                                   ...
# 121657  전자디바이스가 개시된다. 본 발명의 전자디바이스는, 길게 연장된(elongated)...
# 121659  본 발명의 일 실시 예에 따른 디스플레이부를 구비하는 와치 타입 이동 단말기의 동작...
# 121661  이동 단말기 및 그의 제어방법이 개시된다. 본 발명의 이동 단말기 및 그 제어방법은...
# 121665  본 발명은 전면 및 후면을 구비하는 단말기 바디와, 상기 단말기 바디의 어느 일 면...
# 121669  본 발명은, 카메라에 의하여 센싱된 이미지의 일부를 확대 입력 및 이동 입력에 기초...
#
#                                                       발명자  \
# 0                                       박준철(대전광역시 유성구...)
# 2       신동환(대전광역시 유성구...)|안수준(대전광역시 유성구...)|최범(대전광역시 유...
# 5                                       김송권(대전광역시 유성구...)
# 11      조항진(대전광역시 유성구...)|이종수(대전광역시 유성구...)|이지원(대전광역시 ...
# 13                                      임보미(대전광역시 유성구...)
# ...                                                   ...
# 121657                이병화(서울특별시 서초구...)|신충환(서울특별시 서초구...)
# 121659  송영훈(서울특별시 서초구...)|지주민(서울특별시 서초구...)|김융(서울특별시 서...
# 121661                                  모현호(서울특별시 서초구...)
# 121665  김기환(서울특별시 서초구...)|정한용(서울특별시 서초구...)|이용훈(서울특별시 ...
# 121669  정병욱(서울특별시 서초구...)|강승환(서울특별시 서초구...)|설윤환(서울특별시 ...
#
#                                                       대리인  \
# 0                 이강민(서울 강남구 역삼로 *** (역삼동) *층(아인특허법률사무소))
# 2             특허법인필앤온지(서울특별시 서초구 서초중앙로 **, *층(서초동, 준영빌딩))
# 5             특허법인필앤온지(서울특별시 서초구 서초중앙로 **, *층(서초동, 준영빌딩))
# 11                이강민(서울 강남구 역삼로 *** (역삼동) *층(아인특허법률사무소))
# 13                이강민(서울 강남구 역삼로 *** (역삼동) *층(아인특허법률사무소))
# ...                                                   ...
# 121657        특허법인로얄(서울특별시 강남구 테헤란로***길**, *층(대치동, 삼호빌딩))
# 121659  허용록(서울특별시 강남구 역삼로 ***, *층 (역삼동, 현죽빌딩)(선영특허법률사무소))
# 121661        특허법인로얄(서울특별시 강남구 테헤란로***길**, *층(대치동, 삼호빌딩))
# 121665  박장원(서울특별시 강남구  강남대로  ***, *층~*층 (논현동, 비너스빌딩)(박...
# 121669  김용인(서울특별시 송파구 올림픽로 ** (잠실현대빌딩 *층)(특허법인(유한)케이비케...
#
#                                최종권리자 지정국 피인용 횟수  \
# 0                                NaN NaN    NaN
# 2                                NaN NaN    NaN
# 5                                NaN NaN    NaN
# 11      주식회사 엘지에너지솔루션(서울특별시 영등포구...) NaN    1.0
# 13      주식회사 엘지에너지솔루션(서울특별시 영등포구...) NaN    NaN
# ...                              ...  ..    ...
# 121657                           NaN NaN    1.0
# 121659                           NaN NaN    NaN
# 121661                           NaN NaN    NaN
# 121665                           NaN NaN    1.0
# 121669                           NaN NaN    NaN
#
#                                                       청구항
# 0       [청구항1]적어도 둘 이상의 배터리 모듈을 포함하는 배터리 랙을 하나 이상 포함하여...
# 2       [청구항1]전력망 및 적어도 하나의 신재생 발전 장치로부터 전력을 공급 받아 저장하...
# 5       [청구항1]배터리 셀들을 수용할 수 있게 마련된 팩 케이스;상기 팩 케이스의 상부 ...
# 11      [청구항1]복수개의 배터리 랙들이 병렬 연결되어 있는 ESS에 있어서,상기 복수개의...
# 13      [청구항1]에너지저장시스템(ESS)에 포함된 각 배터리 모듈을 구성하는 다수의 셀들...
# ...                                                   ...
# 121657  [청구항1]길게 연장된(elongated) 하우징; 상기 하우징의 일단에 결합된 팁...
# 121659  [청구항1]디스플레이부를 구비하는 와치 타입 이동 단말기의 동작 방법에 있어서,상기...
# 121661  [청구항1]디스플레이부; 및상기 디스플레이부에 표시된 제1 폴더를 제2 폴더와 설정...
# 121665  [청구항1]전면 및 후면을 구비하는 단말기 바디;상기 단말기 바디의 어느 일 면에 ...
# 121669  [청구항1]이미지를 센싱하는 카메라;터치 입력을 수신하고 정보를 디스플레이하는 디스...
#
# [20148 rows x 33 columns]

# %% [markdown]
# # 데이터 탐색

# %%
print(df_filtered.columns.tolist())
# Out:
# ['발명의명칭', '발명의명칭(영문)', 'IPC분류', 'CPC분류', '출원번호', '출원일자', '출원인', '번역문제출일자', '등록번호', '등록일자', '공개번호', '공개일자', '공고번호', '공고일자', '국제출원번호', '국제출원일자', '국제공개번호', '국제공개일자', '우선권정보', '법적상태', '심사진행상태', '원출원번호', '원출원일자', '관련출원번호', '심사청구여부(일자)', '심사청구항수', '요약', '발명자', '대리인', '최종권리자', '지정국', '피인용 횟수', '청구항']

# %%
for column in df_filtered.columns:
    print(f"\nTop 3 representative values for column '{column}':")
    display(df_filtered[column].value_counts().head(3))
# Out:
# Top 3 representative values for column '발명의명칭':
# 발명의명칭
# 이차전지                   202
# 배터리 팩                  194
# 전지 모듈 및 이를 포함하는 전지팩    154
# Name: count, dtype: int64
# Top 3 representative values for column '발명의명칭(영문)':
# 발명의명칭(영문)
# battery module and battery pack including the same     357
# mobile terminal and method for controlling the same    339
# battery pack                                           214
# Name: count, dtype: int64
# Top 3 representative values for column 'IPC분류':
# IPC분류
# H01M 10/04(2015.01)                           222
# H01M 10/0567(2010.01)|H01M 10/052(2010.01)     91
# G09F 9/30(2006.01)|G06F 1/16(2006.01)          53
# Name: count, dtype: int64
# Top 3 representative values for column 'CPC분류':
# CPC분류
# H01M 10/0567(2013.01)|H01M 10/052(2013.01)                           54
# H01M 10/0404(2013.01)|H01M 10/0413(2013.01)|H01M 10/0436(2013.01)    45
# B05C 5/0254(2013.01)|H01M 4/0404(2013.01)                            29
# Name: count, dtype: int64
# Top 3 representative values for column '출원번호':
# 출원번호
# 1020230133500    2
# 1020240132070    2
# 1020200046363    2
# Name: count, dtype: int64
# Top 3 representative values for column '출원일자':
# 출원일자
# 2022.12.23    88
# 2022.12.22    59
# 2015.11.30    39
# Name: count, dtype: int64
# Top 3 representative values for column '출원인':
# 출원인
# 주식회사 엘지에너지솔루션(서울특별시 영등포구...)    11941
# 주식회사 엘지화학(서울특별시 영등포구...)         4403
# 엘지전자 주식회사(서울특별시 영등포구...)         2335
# Name: count, dtype: int64
# Top 3 representative values for column '번역문제출일자':
# 번역문제출일자
# 20190711.0    10
# 20220302.0     6
# 20240523.0     5
# Name: count, dtype: int64
# Top 3 representative values for column '등록번호':
# 등록번호
# 1.026984e+12    2
# 1.022034e+12    2
# 1.022273e+12    2
# Name: count, dtype: int64
# Top 3 representative values for column '등록일자':
# 등록일자
# 2025.01.09    44
# 2025.03.10    34
# 2025.03.31    32
# Name: count, dtype: int64
# Top 3 representative values for column '공개번호':
# 공개번호
# 1.020170e+12    2
# 1.020170e+12    2
# 1.020170e+12    2
# Name: count, dtype: int64
# Top 3 representative values for column '공개일자':
# 공개일자
# 2024.07.02    126
# 2017.10.12    102
# 2024.07.01     84
# Name: count, dtype: int64
# Top 3 representative values for column '공고번호':
# Series([], Name: count, dtype: int64)
# Top 3 representative values for column '공고일자':
# 공고일자
# 2025.04.04    33
# 2021.03.15    32
# 2025.01.10    31
# Name: count, dtype: int64
# Top 3 representative values for column '국제출원번호':
# 국제출원번호
# PCT/KR2016/008400    6
# PCT/KR2017/012737    5
# PCT/KR2018/005071    4
# Name: count, dtype: int64
# Top 3 representative values for column '국제출원일자':
# 국제출원일자
# 2016.07.29    6
# 2022.07.12    6
# 2017.11.10    5
# Name: count, dtype: int64
# Top 3 representative values for column '국제공개번호':
# 국제공개번호
# WO2017119567    6
# WO2018093099    5
# WO2018203652    4
# Name: count, dtype: int64
# Top 3 representative values for column '국제공개일자':
# 국제공개일자
# 2023.10.26    11
# 2022.01.20     8
# 2023.01.19     8
# Name: count, dtype: int64
# Top 3 representative values for column '우선권정보':
# 우선권정보
# 1020230056231 (2023.04.28) 대한민국KR    24
# 1020160090701 (2016.07.18) 대한민국KR    19
# 1020180056166 (2018.05.16) 대한민국KR    18
# Name: count, dtype: int64
# Top 3 representative values for column '법적상태':
# 법적상태
# 공개    9597
# 등록    8264
# 취하    1287
# Name: count, dtype: int64
# Top 3 representative values for column '심사진행상태':
# 심사진행상태
# 등록결정(일반)      7753
# 취하(심사미청구)     1022
# 등록결정(재심사후)     996
# Name: count, dtype: int64
# Top 3 representative values for column '원출원번호':
# 원출원번호
# 1.020230e+12    16
# 1.020230e+12    14
# 1.020230e+12    12
# Name: count, dtype: int64
# Top 3 representative values for column '원출원일자':
# 원출원일자
# 2023.05.24    16
# 2023.04.12    14
# 2023.04.11    12
# Name: count, dtype: int64
# Top 3 representative values for column '관련출원번호':
# 관련출원번호
# 1020180136862    2
# 1020240176496    2
# 1020200028331    2
# Name: count, dtype: int64
# Top 3 representative values for column '심사청구여부(일자)':
# 심사청구여부(일자)
# N                2930
# Y(2025.02.28)     103
# Y(2018.10.02)      85
# Name: count, dtype: int64
# Top 3 representative values for column '심사청구항수':
# 심사청구항수
# 10    2507
# 12    1902
# 11    1889
# Name: count, dtype: int64
# Top 3 representative values for column '요약':
# 요약
# 본 발명은 양극 활물질에 관한 것으로, 종래의 2차 입자의 문제점과, 단입자의 문제점을 동시에 해결할 수 있는 양극 활물질로, 종래의 단입자와 같은 입자를 1차 입자로 포함하고, 복수 개의 1차 입자가 응집되어 형성된 2차 입자를 포함하여, 리튬이차전지의 수명 향상 및 가스 발생량 저감 등의 셀 특성은 물론, 밀도 특성이 우수하여 에너지 밀도를 향상시킬 수 있는 양극 활물질, 이를 포함하는 양극 및 리튬이차전지에 관한 것이다.    18
# 본 출원은 음극 활물질, 음극 활물질의 제조 방법, 음극 조성물, 이를 포함하는 리튬 이차 전지용 음극 및 음극을 포함하는 리튬 이차 전지에 관한 것이다.                                                                                                                                                              14
# 본 발명은 음극 활물질, 이를 포함하는 음극, 이를 포함하는 이차전지 및 음극 활물질의 제조방법에 관한 것이다.                                                                                                                                                                                      13
# Name: count, dtype: int64
# Top 3 representative values for column '발명자':
# 발명자
# 임성현(서울특별시 중구...)     94
# 권명빈(대전광역시 유성구...)    39
# 배수호(서울특별시 중구...)     37
# Name: count, dtype: int64
# Top 3 representative values for column '대리인':
# 대리인
# 특허법인태평양(서울특별시 중구 청계천로 **, *층(다동, 예금보험공사빌딩))    4439
# 특허법인필앤온지(서울특별시 서초구 서초중앙로 **, *층(서초동, 준영빌딩))    3918
# 유미특허법인(서울특별시 강남구 테헤란로 ***, 서림빌딩 **층 (역삼동))     2014
# Name: count, dtype: int64
# Top 3 representative values for column '최종권리자':
# 최종권리자
# 주식회사 엘지에너지솔루션(서울특별시 영등포구...)    6339
# 엘지전자 주식회사(서울특별시 영등포구...)         926
# 주식회사 엘지화학(서울특별시 영등포구...)         557
# Name: count, dtype: int64
# Top 3 representative values for column '지정국':
# Series([], Name: count, dtype: int64)
# Top 3 representative values for column '피인용 횟수':
# 피인용 횟수
# 1.0    2392
# 2.0     911
# 3.0     392
# Name: count, dtype: int64
# Top 3 representative values for column '청구항':
# 청구항
# [청구항1]전지 케이스의 상면에 이격 배치된 양극단자 및 음극단자; 및단자몸체 및 연장단자를 포함하는 단자 구조체;를 포함하고,상기 단자 구조체는,상기 양극단자와 음극단자 중 적어도 어느 하나가 노출되지 않도록 감싸면서 상기 전지 케이스의 상면 및 상기 상면에 이어지는 하나 이상의 면에 결합하고,상기 연장단자는 상기 양극단자 또는 음극단자와 전기적으로 연결되면서 상기 단자몸체 중 상면을 제외한 적어도 어느 일면에 노출되며,상기 단자 구조체에 의해 노출되지 않도록 감싸진 양극단자 및/또는 음극단자는 비활성화되는, 이차전지.\n[청구항2]제1항에 있어서,상기 전지 케이스는 육면체 전지 케이스인, 이차전지.\n[청구항3]제1항에 있어서,상기 연장단자를 상기 양극단자 또는 음극단자에 대해 전기적으로 연결하는 연장배선을 더 포함하고,상기 연장 배선은 상기 단자몸체에 의해 덮혀 있는, 이차전지.\n[청구항4]제3항에 있어서,상기 단자몸체는 절연성 수지 재질로 이루어지고,상기 양극단자 또는 음극단자는 상기 단자몸체에 의해 작동하지 않는 것을 특징으로 하는, 이차전지.\n[청구항5]제1항에 있어서,상기 단자몸체는 상기 전지 케이스의 상면 및 상기 상면에 이어지는 적어도 하나의 측면에 결합하고,상기 연장단자는 상기 상면에 이어지는 적어도 하나의 측면상에 노출되어 있는, 이차전지.\n[청구항6]제5항에 있어서,상기 단자 구조체는 상기 양극단자 및 음극단자에 하나씩 결합하는 것을 특징으로 하는, 이차전지.\n[청구항7]제6항에 있어서,상기 양극단자에 결합한 단자 구조체의 연장단자는 제1 면에 위치하고,상기 음극단자에 결합한 단자 구조체의 연장단자는 제2 면에 위치하는, 이차전지.\n[청구항8]제7항에 있어서,상기 제1 면 및 제2 면은 서로 다른 면인 것을 특징으로 하는, 이차전지.\n[청구항9]제8항에 있어서,상기 제1 면 및 제2 면은 서로 인접한 면인 것을 특징으로 하는, 이차전지.\n[청구항10]제8항에 있어서,상기 제1 면 및 제2 면은 서로 대향하는 면인 것을 특징으로 하는, 이차전지.\n[청구항11]제7항에 있어서,상기 제1 면 및 제2 면은 공통면 상에 위치하는 것을 특징으로 하는, 이차전지.\n[청구항12]제11항에 있어서,상기 제1 면은 상기 제2 면에 대해 상기 공통면 상에서 수직방향을 따라 분리되어 있는 것을 특징으로 하는, 이차전지.\n[청구항13]제11항에 있어서,상기 제1 면은 상기 제2 면에 대해 상기 공통면 상에서 수평방향을 따라 분리되어 있는 것을 특징으로 하는, 이차전지.\n[청구항14]제1항에 있어서,상기 전지 케이스의 일면 상에 구비된 벤팅부를 더 포함하고,상기 연장단자는 상기 벤팅부를 포함하는 면 이외의 다른 면에 위치하는 것을 특징으로 하는, 이차전지.\n[청구항15]제14항에 있어서,상기 벤팅부는, 상기 전지 케이스 상면 상의 상기 양극단자 및 음극단자 사이에 위치하는, 이차전지.\n[청구항16]제1항에 있어서,상기 단자 구조체는 상기 전지 케이스로부터 분리할 수 있는 것을 특징으로 하는, 이차전지.                                                                                                                                                                                                                                                                                                                                                                                                                                                                         3
# [청구항1]충전 장치로부터 무선 충전 전력을 수신하는 무인비행체의 구동 방법에 있어서,GPS 정보에 기초하여 상기 무인비행체가 이동하고, 상기 충전 장치의 위치 정보를 포함하는 무선 신호를 상기 충전 장치로부터 수신하는 단계;상기 GPS 정보와 상기 무선 신호에 포함된 위치 정보의 일치 여부를 판단하고, 상기 GPS 정보와 상기 무선 신호에 기초하여 착륙하는 단계; 및상기 무인비행체의 전력 정보를 포함하는 수신 패킷을 상기 충전 장치로 전송하고, 상기 수신 패킷에 기초하여 생성된 상기 충전 장치의 위치 좌표를 포함하는 정밀 위치 정보를 상기 충전 장치로부터 수신하는 단계를 포함하는 무인비행체의 구동 방법.\n[청구항2]제1항에 있어서,상기 무인비행체의 착륙 위치 정보와 상기 정밀 위치 정보를 비교하고, 상기 착륙 위치 정보와 상기 정밀 위치 정보가 일치하는 경우, 무선 충전 전력을 수신하는 단계를 더 포함하는 무인비행체의 구동 방법.\n[청구항3]제1항에 있어서,상기 무인비행체의 착륙 위치 정보와 상기 정밀 위치 정보를 비교하고, 착륙 위치 정보와 상기 정밀 위치 정보가 일치하지 않는 경우, 상기 정밀 위치 정보에 기초하여 상기 무인비행체가 재착륙하는 단계를 더 포함하는 무인비행체의 구동 방법.\n[청구항4]제1항에 있어서,상기 전력 정보를 포함하는 수신 패킷에 기초하여 상기 전력 정보가 임계값을 초과하면 구동부 전원이 오프되도록 제어하는 단계를 더 포함하는 무인비행체의 구동 방법.\n[청구항5]제1항에 있어서,상기 무인비행체는 몸체부;상기 몸체부와 연결되고 복수의 프로펠러를 포함하는 날개부; 및상기 충전 장치로부터 무선 충전 전력을 수신하는 무선 전력 수신 장치를 장착하는 다리부를 포함하는 무인비행체의 구동 방법.\n[청구항6]제5항에 있어서,상기 무선 전력 수신 장치의 수신 코일의 크기와 형상은, 상기 충전 장치의 송신 코일의 크기와 형상과 동일한 무인비행체의 구동 방법.\n[청구항7]무선 충전 전력을 무인비행체에 전송하는 충전 장치의 구동 방법에 있어서,상기 충전 장치의 AP 정보를 포함하는 무선 신호를 상기 무인비행체에 전송하는 단계; 및상기 무인비행체를 감지하여 디지털 신호를 송신하고, 상기 무인 비행체로부터 수신 패킷을 수신하는 단계; 및상기 수신 패킷에 포함된 무선 전력 수신 장치의 수신 전력 정보에 기초하여 얼라인 여부를 판단하는 단계를 포함하는 충전 장치의 구동 방법.\n[청구항8]제7항에 있어서,상기 수신 패킷이 임계값을 초과하는 경우, 상기 무인비행체에 무선 전력을 충전하는 단계를 더 포함하는 충전 장치의 구동 방법.\n[청구항9]제7항에 있어서,상기 수신 패킷이 임계값 이하인 경우, 상기 수신 패킷에 기초하여 상기 충전 장치의 위치 좌표를 포함하는 정밀 위치 정보를 생성하고, 상기 무인비행체로 생성된 정밀 위치 정보를 송신하는 단계를 더 포함하는 충전 장치의 구동 방법.\n[청구항10]제7항에 있어서,상기 무인비행체의 착륙 지점에 상응하는 다수개의 무선 전력 송신 장치 중 적어도 하나를 선택하는 단계를 더 포함하는 충전 장치의 구동 방법.\n[청구항11]제8항에 있어서,상기 수신 패킷이 임계값 이하인 경우, 상기 수신 패킷 또는 상기 충전 장치의 홀 센서에 감지된 정보에 의해 상기 충전 장치의 위치 좌표를 포함하는 정밀 위치 정보를 생성하고, 상기 무인비행체로 생성된 정밀 위치 정보를 송신하는 단계를 더 포함하는 충전 장치의 구동 방법.\n[청구항12]제7항에 있어서,상기 충전 장치는,송신 코일이 구비된 무선 전력 송신 장치;상기 수신 패킷에 기초하여 상기 충전 장치의 위치 좌표를 포함하는 정밀 위치 정보를 생성하는 제어부; 및상기 정밀 위치 정보를 상기 무인비행체에 전송하는 무선 통신부를 포함하는 충전장치의 구동 방법.\n[청구항13]제12항에 있어서,상기 제어부는, 상기 무인비행체가 얼라인에 실패하는 경우 페어링된 다수개의 무선 전력 송신 장치가 수평 이동하도록 제어하는 충전장치의 구동 방법.    3
# [청구항1]두께 방향으로의 전기화학 반응 불균일성을 확인하고자 하는 전극을 모사한 전지 셀을 포함하는 이차 전지로서, 상기 전지셀은, 두께 방향으로 순차적으로 적층되어 있는 제1 전극, 분리막, 기준전극, 분리막 및 상기 확인하고자 하는 전극에 해당하는 제2 전극을 포함하고,상기 제2 전극은 순차적으로 적층된 상층부, 다공성 필름 및 하층부를 포함하고, 상기 제1 전극, 제2 전극의 상층부 및 제2 전극의 하층부 각각은 집전체 상에 활물질층이 형성된 구조를 가지며, 상기 제1 전극의 집전체, 상기 제2 전극의 상층부의 집전체 및 상기 제2 전극의 하층부의 집전체에는 전극 탭이 연장되어 있는 것을 특징으로 하는 이차 전지.\n[청구항2]제1항에 있어서, 상기 제1 전극은 양극이고, 제2 전극은 음극인 것을 특징으로 하는 이차 전지.\n[청구항3]제1항에 있어서, 상기 제1 전극은 음극이고, 제2 전극은 양극인 것을 특징으로 하는 이차 전지.\n[청구항4]제1항에 있어서, 상기 다공성 필름은 상기 제2 전극의 상층부 및 제2 전극의 하층부 각각보다 큰 다공도를 가지는 것을 특징으로 하는 이차 전지.\n[청구항5](a) 순차적으로 적층된 제1 전극, 분리막, 기준전극, 분리막 및 제2 전극을 포함하되, 상기 제2 전극은 상층부, 다공성 필름 및 하층부가 순차적으로 적층되어 있는 전지셀을 준비하는 단계로서, 상기 제1 전극, 제2 전극의 상층부 및 제2 전극의 하층부 각각은 집전체 상에 활물질층이 형성된 구조를 가지며, 상기 제1 전극의 집전체, 상기 제2 전극의 상층부의 집전체 및 상기 제2 전극의 하층부의 집전체에는 전극 탭이 연장되어 있는 것인 전지셀을 준비하는 단계;(b) 상기 제1 전극, 제2 전극의 상층부 및 제2 전극의 하층부에서 연장된 전극 탭에 전기분석장치를 연결하는 단계;(c) 상기 전지셀을 충전하는 동안 상기 전기분석장치를 이용하여 상기 제2 전극의 상층부와 제2 전극의 하층부 각각의 전류 및 전압을 시간에 따라 측정하는 단계;(d) 상기 전지셀의 충전이 완료된 후, 상기 제2 전극의 상층부와 제2 전극의 하층부 각각의 개방전압을 측정하는 단계; 및(e) 상기 (c) 단계에서 측정된 각각의 전류를 적분하여 상기 제2 전극의 상층부와 제2 전극의 하층부 각각의 충전 용량을 계산하여 서로 비교하고, 상기 (d) 단계에서 측정된 각각의 개방전압을 서로 비교하여, 상기 제2 전극의 상층부와 제2 전극의 하층부간의 전기화학 반응 차이를 분석하는 단계;를 포함하는 이차 전지의 반응 추정 방법.\n[청구항6]제5항에 있어서,상기 (c) 단계에서,상기 제2 전극의 상층부 전극 탭 및 상기 제2 전극의 하층부 전극 탭과 상기 기준 전극 사이의 전압을 측정하여 상기 제2 전극의 상층부 및 상기 제2 전극의 하층부의 전압을 측정하고,상기 제2 전극의 상층부 전극 탭 및 제2 전극의 하층부 전극 탭을 통해 흐르는 전류를 측정하여 상기 제2 전극의 상층부 및 상기 제2 전극의 하층부의 전류를 측정하는 것을 특징으로 하는 이차 전지의 반응 추정 방법.\n[청구항7]제5항에 있어서,상기 (d) 단계에서,상기 전지셀의 충전이 종료된 후의 휴지 시간(resting time) 동안 상기 제2 전극의 상층부 전극 탭 및 제2 전극의 하층부 전극 탭과 상기 기준 전극 사이의 전압을 측정하여 상기 제2 전극의 상층부와 상기 제2 전극의 하층부의 개방전압을 측정하는 것을 특징으로 하는 이차 전지의 반응 추정 방법.\n[청구항8]제5항에 있어서, 상기 제1 전극은 양극이고, 제2 전극은 음극인 것을 특징으로 하는 이차 전지의 반응 추정 방법.\n[청구항9]제5항에 있어서, 상기 제1 전극은 음극이고, 제2 전극은 양극인 것을 특징으로 하는 이차 전지의 반응 추정 방법.\n[청구항10]제5항에 있어서,상기 다공성 필름은 상기 제2 전극의 상층부 및 제2 전극의 하층부 각각보다 큰 다공도를 가지는 것을 특징으로 하는 이차 전지의 반응 추정 방법.      2
# Name: count, dtype: int64

# %% [markdown]
# # 데이터 분석

# %% [markdown]
# # 📊 LG 배터리 특허 데이터 분석 방법론 및 코드 해설
#
# ## 1. 분석 개요 및 환경 설정
# * **목적:** LG 관련 배터리 특허 데이터(`df_filtered`)를 다각도로 분석하여 기술 트렌드, 핵심 인재, 원천 기술을 식별함.
# * **사용 도구:**
#     * **데이터 처리:** `pandas` (데이터 프레임 조작), `re` (정규표현식 텍스트 정제)
#     * **시각화:** `matplotlib`, `seaborn` (차트 시각화), `wordcloud` (텍스트 마이닝)
#     * **AI 분석:** `google.generativeai` (Gemini 1.5 Flash 모델 활용)
# * **환경:** Google Colab (한글 폰트 `NanumBarunGothic` 설치 필수)
#
# ---
#
# ## 2. 단계별 분석 방법 및 코드 로직
#
# ### ① 데이터 전처리 (Preprocessing)
# 원천 데이터의 노이즈를 제거하고 분석 가능한 형태로 가공하는 핵심 단계.
#
# * **날짜 데이터 변환:**
#     * **코드 로직:** `pd.to_datetime(..., errors='coerce')`
#     * **목적:** 문자열(`2023.05.01`)을 시계열 분석이 가능한 `datetime` 객체로 변환. 오류 데이터는 `NaT`로 처리.
# * **IPC(국제특허분류) 코드 단순화:**
#     * **코드 로직:** `text.split('|')[0].split('/')[0]`
#     * **목적:** `H01M 10/052(2010.01)` 처럼 복잡한 코드를 메인 서브클래스(`H01M 10`) 단위로 잘라서 기술 분야를 그룹화함.
# * **출원인/발명자 텍스트 정제:**
#     * **코드 로직:** `re.sub(r'\([^)]*\)', '', text)`
#     * **목적:** 이름 뒤의 주소정보(`(서울특별시...)`)를 정규표현식으로 제거하여 동일 인물/기업을 정확하게 카운팅함.
#
# ### ② 시계열 트렌드 분석 (Time Series Analysis)
# 기술의 성장 단계(태동기-성장기-성숙기)를 파악하기 위한 분석.
#
# * **분석 방법:** 출원일자와 등록일자 기준 연도별 건수 집계 (`value_counts().sort_index()`).
# * **시각화:** 꺾은선 그래프(Line Plot)를 통해 출원량의 우상향 추세 확인.
# * **인사이트:** 최근 3~4년 내 급격한 출원 증가는 기술 투자가 집중되고 있음을 의미.
#
# ### ③ 기술 분야 및 법적 상태 분석 (Technology & Legal Status)
# 어떤 기술에 집중하고 있으며, 권리 확보율은 얼마나 되는지 분석.
#
# * **분석 방법:** 전처리된 `IPC_Main` 컬럼의 빈도수 상위 10개 추출.
# * **시각화:** `sns.countplot`을 사용하여 기술 분야(X축)별 출원 건수(Y축)를 표시하되, `hue='법적상태'` 옵션으로 등록/공개 비율을 동시에 시각화.
# * **핵심 발견:** `H01M 50` (구조/팩/케이스) 분야가 `H01M 10` (소재/셀) 분야보다 압도적으로 많음 → **패키징 기술 중심의 시장 재편.**
#
# ### ④ 핵심 발명자-기술 매핑 (Inventor-Tech Heatmap)
# "누가(Who) 무엇을(What) 연구하는가?"를 규명하는 고난이도 분석.
#
# * **데이터 구조화:** 1.  한 특허에 여러 발명자가 있는 경우 `split('|')`로 분리하여 행(Row)을 늘림 (Explode).
#     2.  발명자별 `IPC_Code` 빈도를 카운팅.
# * **히트맵(Heatmap) 구현:**
#     * `pd.crosstab`으로 발명자(행) × 기술분야(열) 교차표 생성.
#     * **IPC 라벨링:** 암호 같은 코드를 `'H01M 50\n(구조/케이스/팩)'` 형태의 직관적인 한글로 변환하는 매핑 딕셔너리(`ipc_meaning_map`) 적용.
# * **인사이트:** 상위 10명의 에이스 연구원들이 모두 화학 분야가 아닌 **기구 설계(H01M 50)에 집중**하고 있음을 시각적으로 입증.
#
# ### ⑤ 텍스트 마이닝 (WordCloud)
# 특허 제목에서 빈출 키워드를 추출하여 직관적인 이미지를 생성.
#
# * **불용어(Stopwords) 처리 강화:**
#     * 일반적인 불용어 외에 특허 상투어(`조성물`, `방법`, `장치`, `제공`) 및 데이터셋 공통어(`배터리`, `이차전지`)를 제거 리스트에 추가.
#     * **패턴 삭제:** `re.sub(r'\S+하는', ...)` 코드를 사용해 '제조하는', '포함하는' 등 서술어 형태를 통째로 삭제하여 **명사(실질 형태소)**만 남김.
# * **결과:** `냉각`, `모듈`, `프레임`, `커버` 등 실질적인 기술 키워드만 시각화됨.
#
# ### ⑥ 1등 특허 식별 및 AI 심층 분석 (Gemini API)
# 가장 가치 있는 특허를 찾아내어 사람이 읽기 쉽게 요약함.
#
# * **식별 기준:** **피인용 횟수(Forward Citation)**가 가장 많은 특허 (`sort_values(ascending=False)`).
#     * *이유:* 피인용 횟수는 기술적 파급력과 원천성을 나타내는 가장 강력한 지표임.
# * **AI 프롬프트 엔지니어링:**
#     * **역할 부여:** "20년 경력의 배터리 전문 변리사" 페르소나 부여.
#     * **분석 요청:** 핵심 요약, 초등학생도 이해하는 쉬운 설명, 기술적 특징(글머리 기호), 권리 범위 평가 등 구조화된 답변 요구.
#     * **입력 데이터:** 식별된 1등 특허의 `발명의 명칭`과 `청구항(Claims)` 전문을 주입.
#
# ---
#
# ## 3. 분석 결론 요약
# 이 코드를 통해 도출된 결론은 다음과 같습니다.
#
# 1.  **기술 트렌드:** LG의 기술 개발 축이 '화학 소재'에서 **'배터리 팩/모듈 및 양산 구조(H01M 50)'**로 이동하였습니다.
# 2.  **핵심 인재:** 주요 연구 인력들은 전극 소재보다는 **구조 설계 및 엔지니어링** 파트에 집중되어 있습니다.
# 3.  **원천 기술:** 가장 많이 인용된 1등 특허는 **'마찰 교반 용접(FSW)'을 적용한 모듈 케이스** 기술로, 이는 양산성과 안전성을 동시에 확보하기 위한 전략적 특허입니다.

# %%
# [설정] 한글 폰트 및 스타일 (Colab 환경 고려)
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %% [markdown]
# # 📊 LG 배터리 특허 포트폴리오 및 핵심 기술 분석 보고서
#
# ## 1. 거시적 트렌드 및 출원 동향
# * **출원 주체:** 'LG에너지솔루션'이 압도적인 비중을 차지하며, LG화학 및 LG전자가 그 뒤를 이음. 배터리 전문 법인 분사 이후 특허권 확보 활동이 집중됨.
# * **시계열 추이:**
#     * 최근 10년(2015~2025) 간 출원량이 지속적으로 증가함.
#     * 특히 최근 3~4년 내 출원 및 등록 건수가 급증하며 기술 성숙 및 시장 방어 단계로 진입함.
# * **기술의 중심 이동:**
#     * 과거 셀 화학(Chemistry) 중심에서 **모듈/팩 패키징(Packaging) 및 양산 기술**로 무게 중심이 이동함.
#
# ## 2. 주요 기술 분야 (IPC/CPC 및 키워드 분석)
# * **핵심 기술 분야 (IPC H01M 50의 부상):**
#     * **H01M 50 (구조/케이스/팩):** 가장 높은 비중을 차지. 단순 전지 제조를 넘어 전기차(EV) 탑재를 위한 구조적 안전성, 모듈화 기술에 R&D 역량이 집중됨.
#     * **H01M 10 (이차전지 일반):** 기본 셀 성능 및 제조 공정에 대한 연구도 꾸준히 유지됨.
# * **주요 키워드 (워드클라우드):**
#     * `모듈`, `케이스`, `냉각`, `프레임`, `커버` 등 하드웨어/기구 설계 관련 용어가 지배적.
#     * 이는 배터리의 **열 관리(Cooling)**와 **구조적 보호(Protection)**가 현재 기술 개발의 최우선 순위임을 시사함.
#
# ## 3. 핵심 인적 자원 (Inventors Analysis)
# * **발명자 집중도:**
#     * 상위 10명의 핵심 발명자(예: 문정오 등)가 대부분 **H01M 50 (구조/팩/케이스)** 분야에 포진함.
#     * 소재/화학 분야보다는 기구 설계 및 엔지니어링 파트의 인력이 특허 다작(多作)을 주도하고 있음.
# * **R&D 전략:** 소수의 핵심 리더가 배터리 팩/모듈의 구조 설계를 총괄하며 강력한 특허 장벽을 구축하는 전략을 취함.
#
# ---
#
# ## 4. [심층 분석] 1등 특허 (가장 많이 인용된 기술)
# **"LG 배터리 모듈 기술의 정수: 마찰 교반 용접(FSW)을 적용한 케이스"**
#
# ### ① 서지 정보
# * **발명의 명칭:** 배터리 모듈 (Battery Module)
# * **출원 번호:** 10-2016-0122320
# * **피인용 횟수:** 22회 (해당 데이터셋 내 1위, 기술적 파급력이 매우 큼)
# * **기술 분류:** H01M 10/6554 (냉각 구조), H01M 50 (구조)
#
# ### ② 핵심 기술 요약
# * **기술 개요:** 다수의 파우치형 전지를 감싸는 모듈 케이스를 조립할 때, 나사나 접착제 대신 **'마찰 교반 용접(FSW)'** 기술을 사용하여 부품을 일체화하는 기술.
# * **작동 원리 (쉬운 설명):**
#     * 금속을 녹이지 않고 고속으로 비벼서 발생하는 마찰열로 접합함 (마치 찰흙 두 덩이를 문질러 하나로 만드는 것과 유사).
#     * 기존 용접 대비 변형이 적고, 접합 강도가 매우 높으며 밀폐력이 뛰어남.
#
# ### ③ 기술적 특징 (Key Features)
# * **6면체 모듈 케이스 구조:**
#     *
#     * 쿨링 플레이트(바닥) + 셀 어셈블리(배터리 뭉치) + 커버(전/후/좌/우/상)의 완벽한 결합.
# * **마찰 교반 용접(FSW) 적용:**
#     * 모든 케이스 부품 간의 연결에 FSW를 적용하여 체결 부품(볼트/너트)을 제거, 경량화 및 공간 효율성 극대화.
# * **맞대기 용접(Butt Joint) 설계:**
#     * 부재를 겹치지 않고 모서리를 맞대어 용접함으로써 전체 모듈의 부피를 줄이고 매끄러운 외관 확보.
#
# ### ④ 권리 범위 및 가치 평가
# * **특허 성격:** 특정 제조 공법(FSW)과 조립 구조를 한정한 **'공정 및 구조 개선 특허'**.
# * **권리 범위:**
#     * 광범위한 원천 특허라기보다는, **'FSW 용접을 사용한 특정 형태의 파우치형 모듈'**로 한정됨.
#     * 하지만 경쟁사가 동일한 방식(FSW)으로 고품질 모듈을 제조하려 할 때 반드시 회피해야 하는 강력한 길목 특허임.
# * **시장 가치:** 피인용 수가 높은 이유는 이 기술이 배터리 팩의 **경량화**, **고강도화**, **방수/방진(밀폐)** 문제를 동시에 해결하는 가장 효율적인 솔루션 중 하나이기 때문임.
#
# ---
#
# ## 5. 종합 결론 및 인사이트
# 1.  **Hard-Ware 중심의 진화:** LG의 특허 데이터는 배터리 산업이 '화학적 성능 경쟁'을 넘어 **'안전하고 효율적인 패키징 경쟁'**으로 넘어갔음을 명확히 보여줌.
# 2.  **1등 특허의 시사점:** 가장 많이 인용된 특허가 '화학 물질'이 아닌 **'용접/조립 기술'**이라는 점은, 현재 배터리 시장에서 **양산성(Mass Production)**과 **신뢰성(Reliability)** 확보가 얼마나 중요한지를 반증함.
# 3.  **대응 전략:** 경쟁사 분석 시 LG의 H01M 50 분야(팩/모듈 구조) 특허망을 정밀 분석하여 회피 설계를 하거나, FSW 외의 다른 접합 솔루션(레이저 용접 등)을 모색해야 함.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# ==========================================
# [0] 라이브러리 및 폰트 설정 (Colab용)
# ==========================================
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from collections import Counter
import re
import google.generativeai as genai
from google.colab import userdata

# 한글 폰트 설정
plt.rc('font', family='NanumBarunGothic')
plt.rcParams['axes.unicode_minus'] = False
sns.set(font='NanumBarunGothic', style='whitegrid')

# ==========================================
# [1] 데이터 전처리
# ==========================================
def preprocess_patent_data(df):
    df = df.copy()

    # 1. 날짜 컬럼 변환
    date_cols = ['출원일자', '등록일자', '공개일자', '공고일자']
    for col in date_cols:
        df[col] = pd.to_datetime(df[col], errors='coerce')

    # 2. IPC 메인 그룹 추출 (Subclass 레벨)
    def extract_main_code(text):
        if pd.isna(text): return "Unknown"
        first_code = text.split('|')[0]
        return first_code.split('/')[0]

    df['IPC_Main'] = df['IPC분류'].apply(extract_main_code)
    return df

# ★ 데이터 로드 (df_filtered가 이미 있다고 가정)
# 만약 엑셀파일을 다시 읽어야 한다면 아래 주석 해제
# df_filtered = pd.read_excel('/content/경로/파일명.xlsx')

df_clean = preprocess_patent_data(df_filtered)

# ==========================================
# [2] 시계열 분석 (출원/등록 추이)
# ==========================================
df_clean['출원년도'] = df_clean['출원일자'].dt.year
df_clean['등록년도'] = df_clean['등록일자'].dt.year

app_trend = df_clean['출원년도'].value_counts().sort_index()
reg_trend = df_clean['등록년도'].value_counts().sort_index()

plt.figure(figsize=(14, 5))
plt.plot(app_trend.index, app_trend.values, marker='o', label='출원 건수', linewidth=2)
plt.plot(reg_trend.index, reg_trend.values, marker='s', linestyle='--', label='등록 건수', linewidth=2)
plt.title('연도별 특허 출원 및 등록 추이', fontsize=16)
plt.xlabel('연도')
plt.ylabel('건수')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# ==========================================
# [3] IPC 기술 분야 분석
# ==========================================
print("\n### 핵심 기술 분야(IPC Main) 상위 10개 ###")
top_ipc = df_clean['IPC_Main'].value_counts().head(10).index
df_ipc_top = df_clean[df_clean['IPC_Main'].isin(top_ipc)]

plt.figure(figsize=(14, 7))
sns.countplot(data=df_ipc_top, x='IPC_Main', hue='법적상태', order=top_ipc, palette='viridis')
plt.title('주요 기술 분야별 특허 법적 상태', fontsize=18)
plt.xlabel('IPC 기술 분류', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# ==========================================
# [4] 출원인 분석 (괄호 제거)
# ==========================================
all_applicants = []
for item in df_clean['출원인']:
    if pd.notnull(item):
        cleaned = re.sub(r'\([^)]*\)', '', item) # 괄호 제거
        all_applicants.append(cleaned.strip())

top_applicants = pd.Series(all_applicants).value_counts().head(10)

plt.figure(figsize=(10, 5))
sns.barplot(x=top_applicants.values, y=top_applicants.index, palette='magma')
plt.title('상위 10개 출원인', fontsize=15)
plt.show()

# ==========================================
# [5] 핵심 발명자 히트맵 (★ 발명자별 특허 총 개수 열 추가됨)
# ==========================================
# 1. IPC 코드 해석 사전
ipc_meaning_map = {
    'H01M 50': 'H01M 50\n(구조/케이스/팩)',
    'H01M 10': 'H01M 10\n(이차전지 일반)',
    'H01M 4':  'H01M 4\n(전극/활물질)',
    'H01M 52': 'H01M 52\n(스택/적층구조)',
    'B60L 50': 'B60L 50\n(전기차 추진)',
    'B60L 53': 'B60L 53\n(충전 시스템)',
    'B60L 58': 'B60L 58\n(BMS/제어)',
    'G01R 31': 'G01R 31\n(테스트/검사)',
    'H01G 11': 'H01G 11\n(슈퍼커패시터)',
    'H01M 8':  'H01M 8\n(연료전지)'
}

# 2. 데이터 준비
inventor_tech = []
for idx, row in df_clean.iterrows():
    if pd.isna(row['발명자']): continue

    raw_inventors = re.sub(r'\([^)]*\)', '', row['발명자'])
    inventors = [inv.strip() for inv in raw_inventors.split('|')]
    ipc_code = row['IPC_Main'].strip()

    for inv in inventors:
        inventor_tech.append({'발명자': inv, 'IPC_Code': ipc_code})

df_inv_tech = pd.DataFrame(inventor_tech)

# ⭐️ 추가 코드 1: 발명자별 특허 총 개수 계산
patent_counts = df_inv_tech['발명자'].value_counts().rename('특허 총 개수')
df_patent_counts = patent_counts.reset_index().rename(columns={'index': '발명자'})

# 3. 상위 추출 및 필터링
top_inventors = df_inv_tech['발명자'].value_counts().head(10).index
top_ipcs = df_inv_tech['IPC_Code'].value_counts().head(10).index

# 상위 10개 발명자 목록에 해당하는 특허 개수 데이터프레임 필터링
df_top_counts = df_patent_counts[df_patent_counts['발명자'].isin(top_inventors)]


df_filtered_heatmap = df_inv_tech[
    (df_inv_tech['발명자'].isin(top_inventors)) &
    (df_inv_tech['IPC_Code'].isin(top_ipcs))
]

# 4. IPC 라벨 변환 및 시각화 (수정)
df_filtered_heatmap['IPC_Label'] = df_filtered_heatmap['IPC_Code'].apply(
    lambda x: ipc_meaning_map.get(x, x)
)
heatmap_data = pd.crosstab(df_filtered_heatmap['발명자'], df_filtered_heatmap['IPC_Label'])

# ⭐️ 추가 코드 2: 히트맵 데이터와 특허 총 개수 데이터 병합
# 발명자를 인덱스로 설정
heatmap_data = heatmap_data.reset_index().set_index('발명자')
df_top_counts = df_top_counts.set_index('발명자')

# 두 데이터프레임을 병합 (특허 총 개수 열 추가)
merged_heatmap_data = pd.merge(
    df_top_counts[['특허 총 개수']], # 총 개수 열만 선택
    heatmap_data,
    left_index=True,
    right_index=True,
    how='inner'
)
merged_heatmap_data = merged_heatmap_data.sort_values(by='특허 총 개수', ascending=False) # 총 개수 기준으로 정렬

# 시각화
plt.figure(figsize=(16, 9)) # figsize를 약간 늘려줍니다.
sns.heatmap(merged_heatmap_data, annot=True, fmt='d', cmap='YlGnBu', linewidths=.5)
plt.title('핵심 발명자(Key Man)의 주력 기술 분야 (총 개수 포함)', fontsize=18)
plt.xlabel('기술 분야 (IPC)', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.ylabel('발명자', fontsize=14)
plt.tight_layout()
plt.show()

# ==========================================
# [6] 1등 특허 식별 (피인용 횟수 기준)
# ==========================================
top_cited_patent = df_clean.sort_values(by='피인용 횟수', ascending=False).head(1)
best_claim = ""
best_title = ""

print("\n### 🏆 가장 많이 인용된 1등 특허 정보 ###")
if not top_cited_patent.empty:
    # display()는 Colab 환경에서 동작하는 함수이며, 일반 파이썬 환경에서는 print로 대체해야 합니다.
    # 여기서는 제공된 코드 구조를 유지합니다.
    try:
        from IPython.display import display
        display(top_cited_patent[['발명의명칭', '출원번호', '피인용 횟수', 'IPC분류']].T)
    except ImportError:
        print(top_cited_patent[['발명의명칭', '출원번호', '피인용 횟수', 'IPC분류']].T)

    best_claim = top_cited_patent['청구항'].values[0]
    best_title = top_cited_patent['발명의명칭'].values[0]
else:
    print("피인용 횟수 데이터가 없습니다.")

# ==========================================
# [7] 워드클라우드 (★ 강력 필터링 적용됨)
# ==========================================
text_corpus = ' '.join(df_clean['발명의명칭'].astype(str))

# 1. 불필요한 문구 강제 삭제
text_corpus = text_corpus.replace('이를 포함하는', '')
text_corpus = text_corpus.replace('이를', '')
text_corpus = text_corpus.replace('포함하는', '')
text_corpus = re.sub(r'\b그\b', '', text_corpus) # '그' 단독 제거
text_corpus = re.sub(r'\S+하는', '', text_corpus) # '~하는'으로 끝나는 어절 제거

# 2. 불용어 리스트
stopwords = {
    '발명의', '명칭', '방법', '장치', '시스템', '제조', '단계', '특징', '구비', '제공', '조성물', '사용', '이용',
    '및', '위한', '또는', '통한', '관한', '포함', '상기', '의', '에', '를', '은', '는', '이', '가',
    '배터리', '전지', '이차전지', '모듈', '팩', '셀'
}

font_path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'

try:
    wordcloud = WordCloud(
        font_path=font_path,
        width=1000, height=500,
        background_color='white',
        colormap='Dark2',
        stopwords=stopwords,
        regexp=r"[가-힣a-zA-Z]+"
    ).generate(text_corpus)

    plt.figure(figsize=(12, 6))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title('핵심 기술 키워드 (불용어 제거됨)', fontsize=16)
    plt.show()
except Exception as e:
    print(f"워드클라우드 오류: {e}")

# ==========================================
# [8] Gemini API 분석 (최신 모델)
# ==========================================
print("\n========== [Gemini AI 특허 분석 시작] ==========")

if best_claim:
    try:
        # Colab 환경에서 실행하려면 'Gemini_API_KEY'를 Secrets에 저장해야 합니다.
        GOOGLE_API_KEY = userdata.get('Gemini_API_KEY')
        genai.configure(api_key=GOOGLE_API_KEY)

        # 모델: gemini-2.5-flash
        model = genai.GenerativeModel('gemini-2.5-flash')

        patent_claim_short = best_claim[:3000]

        prompt = f'''
        당신은 20년 경력의 배터리 분야 전문 변리사입니다.
        아래 특허의 [청구항]을 분석하여 다음 내용을 작성해주세요.

        1. [핵심 요약]: 이 기술이 무엇인지 한 문장으로 요약하세요.
        2. [쉬운 설명]: 기존 기술과 비교했을 때 어떤 점이 혁신적인지 초등학생도 이해할 수 있게 설명하세요.
        3. [기술적 특징]: 이 특허가 보호하고자 하는 핵심 구성요소 3가지를 글머리 기호로 나열하세요.
        4. [권리 범위 평가]: 청구항의 구조를 보았을 때 권리 범위가 넓은 원천 기술인지, 특정 구현에 한정된 기술인지 평가하세요.

        [특허 정보]
        - 명칭: {best_title}
        - 청구항: {patent_claim_short}...
        '''

        print(f"분석 대상: {best_title}")
        print("Gemini가 분석 중입니다... (모델: gemini-2.5-flash)\n")
        response = model.generate_content(prompt)
        print("--------- [Gemini 분석 결과] ---------")
        print(response.text)
        print("--------------------------------------")

    except Exception as e:
        print(f"❌ Gemini API 오류: {e}")
        print("👉 Google Colab '비밀(Secrets)'에 'Gemini_API_KEY'가 있는지 확인하세요.")
else:
    print("분석할 1등 특허가 없습니다.")
# Out:
# ### 핵심 기술 분야(IPC Main) 상위 10개 ###
# /tmp/ipython-input-49391978.py:90: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_applicants.values, y=top_applicants.index, palette='magma')
# /tmp/ipython-input-49391978.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered_heatmap['IPC_Label'] = df_filtered_heatmap['IPC_Code'].apply(
# ### 🏆 가장 많이 인용된 1등 특허 정보 ###
#                                                      1468
# 발명의명칭                                              배터리 모듈
# 출원번호                                        1020160122320
# 피인용 횟수                                               22.0
# IPC분류   H01M 10/6554(2014.01)|H01M 10/613(2014.01)|H01...
# ========== [Gemini AI 특허 분석 시작] ==========
# 분석 대상: 배터리 모듈
# Gemini가 분석 중입니다... (모델: gemini-2.5-flash)
#
# --------- [Gemini 분석 결과] ---------
# 20년 경력의 배터리 분야 전문 변리사로서, 제시된 특허의 청구항을 분석하여 다음 내용을 작성합니다.
#
# ---
#
# ### [특허 분석 결과]
#
# #### 1. [핵심 요약]
# 이 특허는 파우치형 이차 전지를 수용하는 배터리 모듈의 케이스를 구성하는 여러 부품들을 **마찰 교반 용접(Friction Stir Welding) 방식으로, 단부가 겹치지 않고 모서리가 맞닿는 형태로 연속적으로 용접하여 고강도 및 밀봉성을 확보한 배터리 모듈** 기술입니다.
#
# #### 2. [쉬운 설명]
# 친구들이 스마트폰이나 전기차에 들어가는 배터리 알지? 그 배터리들이 튼튼하고 안전하게 들어있는 "상자"를 만드는 방법에 대한 특허야.
#
# 옛날에는 이 배터리 상자를 만들 때 여러 조각들을 그냥 붙이거나(접착) 쇠를 녹여서 붙이는(일반 용접) 방법을 썼어. 그런데 이렇게 하면 상자가 조금 약하거나, 물이나 먼지가 들어갈 틈이 생길 수도 있었지.
#
# 이 특허는 배터리 상자를 만드는 방법을 아주 특별하고 똑똑하게 바꾼 거야. 마치 찰흙 반죽하듯이, 쇠붙이를 녹이지 않고 아주 강한 도구를 빠르게 비벼서 쇠 조각들을 서로 완전히 섞이게 만들어 붙이는 "마찰 교반 용접"이라는 방법을 쓴 거야. 게다가 쇠 조각들을 서로 겹치지 않고 딱 옆으로 맞대어서 붙이기 때문에 틈새가 거의 없이 아주 매끈하고 튼튼한 상자를 만들 수 있어. 그리고 이 용접선이 끊어지지 않고 쭉 이어져 있어서 상자가 더욱 단단하고 물이나 먼지가 절대 들어올 수 없게 돼!
#
# 이렇게 만들면 배터리 상자가 훨씬 튼튼하고 안전해져서 배터리를 오랫동안 안심하고 사용할 수 있단다. 마치 아주 튼튼한 로봇 팔이 배터리 상자를 빈틈없이 척척 붙여주는 것과 같아!
#
# #### 3. [기술적 특징]
# 이 특허가 보호하고자 하는 핵심 구성요소 및 특징은 다음과 같습니다.
#
# *   **마찰 교반 용접(Friction Stir Welding, FSW) 방식 적용:** 모듈 케이스를 구성하는 쿨링 플레이트, 프론트/리어 커버, 좌우 사이드 커버, 어퍼 플레이트 등 모든 주요 부품들을 접합하는 데 **마찰 교반 용접 방식**을 사용합니다. 이는 기존 용접 방식 대비 낮은 열 변형, 고강도 접합, 이종 재료 접합 등에 유리합니다.
# *   **비겹침 맞대기 용접 구조:** 사이드 커버와 다른 케이스 부품 간 용접 시, **단부가 서로 겹쳐지지 않고 모서리가 서로 맞대어진 상태**로 용접하는 구조를 채택하여, 접합부의 두께 변화를 최소화하고 깔끔하며 균일한 접합면을 형성합니다.
# *   **연속적인 직선 형태의 용접부:** 용접부가 일단에서 타단까지 **하나의 직선 형태로 연속적으로 형성**되어, 용접 라인 전체의 강성 및 밀봉성을 극대화하고 구조적 안정성을 향상시킵니다. (청구항 8은 이에 대한 불연속적인 용접부의 대안을 제시하여 권리범위를 보완하고 있습니다.)
#
# #### 4. [권리 범위 평가]
# 제시된 청구항1의 구조를 볼 때, 이 특허의 권리 범위는 **특정 구현에 한정된 기술**로 평가할 수 있습니다.
#
# *   **청구항1은 배터리 모듈의 구성 요소를 상세하게 나열**하고 있으며, 특히 모듈 케이스의 **"마찰 교반 용접 방식"**, **"단부가 서로 겹쳐지지 않고 모서리가 서로 맞대어진 상태"**, 그리고 **"하나의 직선 형태로 연속적으로 형성된"** 용접부에 대한 특정하고 구체적인 제조/결합 방식을 명시하고 있습니다.
# *   이러한 특정 용접 방식(FSW)과 접합부의 형태, 그리고 용접 라인의 연속성을 명시함으로써, 일반적인 배터리 모듈 케이스 구조가 아닌, **특정한 제조 공정 및 그 결과물인 구조적 특징에 초점**을 맞추고 있습니다.
# *   따라서, 만약 경쟁사가 배터리 모듈 케이스를 조립할 때 마찰 교반 용접 방식이 아닌 다른 용접 방식(예: 레이저 용접, 아크 용접)을 사용하거나, 용접 시 단부가 겹치는 랩 조인트(lap joint) 방식을 사용하거나, 용접부가 연속적이지 않은 형태로 구현한다면, 청구항1의 권리 범위에서 벗어날 가능성이 큽니다.
# *   물론, 청구항3에서 재질을, 청구항4에서 절연코팅을, 청구항5에서 열전달 물질을, 그리고 청구항8에서 불연속 용접을, 청구항9~13에서 용접부 형상 및 단차 등 다양한 종속항을 통해 권리 범위를 보완하고 있지만, 독립항인 청구항1 자체가 특정 구현에 대한 상세한 제약 조건을 포함하고 있어 **원천 기술이라기보다는 특정 제조 방법 및 구조 개선에 대한 개량 발명**에 가깝다고 판단됩니다.
#
# 종합적으로 볼 때, 이 특허는 특정 용접 기술을 활용하여 배터리 모듈 케이스의 성능(강도, 밀봉성)을 향상시킨 매우 유용한 기술이지만, 해당 용접 방식과 구조에 묶여 있기 때문에 권리 침해 주장의 입증이 특정 조건에서 용이한 반면, 권리 범위가 넓다고 보기는 어렵습니다.
# --------------------------------------
